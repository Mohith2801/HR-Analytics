# %% [markdown]
# 1.   "People Charm", a growing company is facing high attrition rate among their employees which turn affects their business due to lack of experties and experience.
# 2.   Their HR department is assigned the task to reduce the attrition rate by retaining employees who are about to churn out.
# 3.   They need to recommend special plans or strategies which will help them to retain their employees which in turn will help them to grow bigger as a company

# %% [markdown]
# ![Screenshot 2025-07-21 211534.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\narra\OneDrive\Desktop\projects\Data Analytics\HR_Analytics\employe (1).csv')

# %%
df
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %% [markdown]
# EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfactoryLevel      14999 non-null  float64
#  1   lastEvaluation         14999 non-null  float64
#  2   numberOfProjects       14999 non-null  int64
#  3   avgMonthlyHours        14999 non-null  int64
#  4   timeSpent.company      14999 non-null  int64
#  5   workAccident           14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotionInLast5years  14999 non-null  int64
#  8   dept                   14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
# Out:
# satisfactoryLevel        0
# lastEvaluation           0
# numberOfProjects         0
# avgMonthlyHours          0
# timeSpent.company        0
# workAccident             0
# left                     0
# promotionInLast5years    0
# dept                     0
# salary                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 3008

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
sns.boxplot(df['avgMonthlyHours'])
#checking outliers
# outliers are nothing but things that are deviated from other observations in the data
# Out:
# <Axes: ylabel='avgMonthlyHours'>

# %%
sns.boxplot(df['numberOfProjects'])
# Out:
# <Axes: ylabel='numberOfProjects'>

# %%
sns.boxplot(df['timeSpent.company'])
# Out:
# <Axes: ylabel='timeSpent.company'>

# %% [markdown]
# the dots are the outliers

# %%
df.columns
# Out:
# Index(['satisfactoryLevel', 'lastEvaluation', 'numberOfProjects',
#        'avgMonthlyHours', 'timeSpent.company', 'workAccident', 'left',
#        'promotionInLast5years', 'dept', 'salary'],
#       dtype='object')

# %% [markdown]
# Checking how "number of projects" is affecting the attrition rate?

# %%
sns.countplot(data=df, x='numberOfProjects', hue='left')
# Out:
# <Axes: xlabel='numberOfProjects', ylabel='count'>

# %% [markdown]
# It is better to give projects between 3-5 per head to avoid over burden

# %% [markdown]
# Checking how "average monthly hours" is affecting the attrition rate?

# %%
sns.histplot(data=df, x='avgMonthlyHours', hue='left',bins=10)
# Out:
# <Axes: xlabel='avgMonthlyHours', ylabel='Count'>

# %% [markdown]
# we can suggest between 100 and 200 AVGMONTHLYHOURs are better

# %% [markdown]
# Checking for promotions

# %%
sns.countplot(data=df, x='promotionInLast5years', hue='left')
# Out:
# <Axes: xlabel='promotionInLast5years', ylabel='count'>

# %% [markdown]
# Not most, some employees without any promotions for past 5 years are leaving the company
